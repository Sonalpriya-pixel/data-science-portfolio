# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonalpriya-pixel/data-science-portfolio/blob/main/sample_student_performance_ds6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sample_student_performance.csv")

# %%
df
# Out:
#     gender  age  study_time  failures  absences  G1  G2  G3
# 0     male   21           1         3         6  13   4  10
# 1   female   16           4         2         2   7  13  16
# 2     male   16           1         0         7   8  15  12
# 3     male   18           4         2         9  10  17  10
# 4     male   16           3         1         5   0   6   1
# ..     ...  ...         ...       ...       ...  ..  ..  ..
# 95  female   21           4         2         7  13  14  12
# 96  female   21           3         3         8  10  19  12
# 97  female   19           4         1         4  15  18  17
# 98  female   21           3         0         6   3   2   2
# 99    male   17           3         2         4  19  19   6
#
# [100 rows x 8 columns]

# %%
df.describe()
# Out:
#               age  study_time    failures    absences         G1          G2  \
# count  100.000000  100.000000  100.000000  100.000000  100.00000  100.000000
# mean    18.160000    2.480000    1.800000    4.980000    9.88000    8.990000
# std      2.154253    1.158892    1.145919    2.453528    6.32021    5.909238
# min     15.000000    1.000000    0.000000    0.000000    0.00000    0.000000
# 25%     16.000000    1.000000    1.000000    3.000000    5.00000    4.000000
# 50%     18.000000    2.000000    2.000000    5.000000   10.00000    9.000000
# 75%     20.000000    4.000000    3.000000    7.000000   16.00000   14.000000
# max     21.000000    4.000000    3.000000   12.000000   19.00000   19.000000
#
#                G3
# count  100.000000
# mean     9.810000
# std      5.361093
# min      0.000000
# 25%      6.000000
# 50%     10.000000
# 75%     15.000000
# max     19.000000

# %%
sns.histplot(df['G3'],kde = True)
plt.title('Distribution of Final Grade')
plt.xlabel('Final Grade for G3')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(data = df[['G1', 'G2', 'G3']])
plt.title("Boxplot for grades")
plt.show()

# %%
print(df.columns)
# Out:
# Index(['age', 'study_time', 'failures', 'absences', 'G1', 'G2', 'G3',
#        'gender_number'],
#       dtype='object')

# %%
df['gender_number'] = df['gender'].map({'male': 1, 'female': 0})
df.drop('gender', axis=1, inplace=True)
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-c25a4961ff84> in <cell line: 0>()
# ----> 1 df['gender_number'] = df['gender'].map({'male': 1, 'female': 0})
# ...

# %%
grouped = df.groupby(['gender_number', 'study_time'])['G3'].mean().unstack()
grouped.plot(kind='bar')
plt.title('Average Final Grade (G3) by Gender and Study Time')
plt.xlabel('Average G3')
plt.show()

# %%
summary = df.describe()
summary.to_csv('summary_statistics.csv')
print("Summary statistics saved to summary_statistics.csv")
# Out:
# Summary statistics saved to summary_statistics.csv
